# %%
import os
import pandas as pd
import matplotlib as plt
from pprint import pprint
from config import gkey

# %%
data_path = os.path.join('..', '..', 'data', 'get_it_done_311_requests_data_subset_.csv')
seperated_date_time_df = pd.read_csv(data_path)
seperated_date_time_df.head()
# Out:
#    Unnamed: 0  service_request_id status_description mobile_web_status  \
# 0           0              384125                New               New
# 1           1              384123                New               New
# 2           2              384122                New               New
# 3           3              384121                New               New
# 4           4              384120                New               New
#
#    duplicate_verified  override_duplicate functional_location  source  \
# 0                   0                   0                 NaN  Mobile
# 1                   0                   0           SS-017056  Mobile
# 2                   0                   0           SS-000449  Mobile
# 3                   0                   0           SS-000449  Mobile
# 4                   0                   0           SS-030478  Mobile
#
#     requested_datetime closed_date   ...    agency_responsible  service_name  \
# ...

# %%
seperated_date_time_df['date_split'], seperated_date_time_df["time_split"] = seperated_date_time_df['requested_datetime'].str.split('T').str
seperated_date_time_df.head()
# Out:
#    Unnamed: 0  service_request_id status_description mobile_web_status  \
# 0           0              384125                New               New
# 1           1              384123                New               New
# 2           2              384122                New               New
# 3           3              384121                New               New
# 4           4              384120                New               New
#
#    duplicate_verified  override_duplicate functional_location  source  \
# 0                   0                   0                 NaN  Mobile
# 1                   0                   0           SS-017056  Mobile
# 2                   0                   0           SS-000449  Mobile
# 3                   0                   0           SS-000449  Mobile
# 4                   0                   0           SS-030478  Mobile
#
#     requested_datetime closed_date    ...     service_subtype        lat  \
# ...
